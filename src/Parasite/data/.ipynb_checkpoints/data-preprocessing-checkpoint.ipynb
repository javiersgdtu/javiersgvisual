# %%
import pandas as pd; 
import numpy as np;
from datetime import datetime, date;
import json;
from collections import OrderedDict;
import seaborn as sns;
import matplotlib.pyplot as plt;
from pylab import savefig

# %% [markdown]
# # Functions

# %%
#Function to merge intervals of time. From https://stackoverflow.com/questions/58570094/pandas-sum-time-interval-in-a-group-excluding-overlaps
def merge_intervals(intervals):
    sorted_by_lower_bound = sorted(intervals, key=lambda tup: tup[0])
    merged = []

    for higher in sorted_by_lower_bound:
        if not merged:
            merged.append(higher)
        else:
            lower = merged[-1]
            # test for intersection between lower and higher:
            # we know via sorting that lower[0] <= higher[0]
            if higher[0] <= lower[1]:
                upper_bound = max(lower[1], higher[1])
                merged[-1] = (lower[0], upper_bound)  # replace by merged interval
            else:
                merged.append(higher)
    return merged

# %%
#-------------------------------------------------Example----------------------------------------------
ids = [x for x in range(10)]
group = [0, 1, 1, 2, 2, 3, 4, 4, 4, 4]

start = pd.to_datetime(["2019-10-21-16:20:00", "2019-10-21-16:22:00", "2019-10-21-16:22:00", "2019-10-21-16:15:00",
         "2019-10-21-16:22:00", "2019-10-21-16:58:00", "2019-10-21-17:02:00", "2019-10-21-17:03:00",
         "2019-10-21-17:04:00", "2019-10-21-17:20:00"])

end = pd.to_datetime(["2019-10-21-16:25:00", "2019-10-21-16:24:00", "2019-10-21-16:24:00", "2019-10-21-16:18:00",
       "2019-10-21-16:26:00", "2019-10-21-17:02:00", "2019-10-21-17:06:00", "2019-10-21-17:07:00",
       "2019-10-21-17:08:00", "2019-10-21-17:22:00"])

cols = ["id", "group", "start", "end"]


df = pd.DataFrame(dict(zip(cols, [ids, group, start, end])))
print(df.head())
# Apply above function
df['dt'] = df[['start', 'end']].apply(tuple, axis=1) #Create a tuple (Date1,Date2)
op = df.groupby(['group'])['dt'].apply(list)  #Create of all intervals grouped.
f_op = op.apply(merge_intervals)   #Use above function to create a grouped list of min,max of each overlaped interval.

op_d = f_op.apply(lambda x: sum([(y[1]-y[0]).seconds for y in x]))
#############################################################################################################################

# %% [markdown]
# # Data

# %% [markdown]
# ## Scenes

# %%
df_raw=pd.read_csv("scenes.csv",encoding = "ISO-8859-1",header=1,sep=";")
# dtype={'Selection starts': np.datetime64, 'Selection ends': np.datetime64}

# %%
df=df_raw.copy()
df.dtypes
# Out:
# scene               float64
# description          object
# location             object
# sublocation          object
# character            object
# Selection starts     object
# Selection ends       object
# Diff.                object
# State                object
# Movement             object
# Note                 object
# dtype: object

# %% [markdown]
# ### Preprocessing

# %%
#df[['Selection starts','Selection ends']]=df[['Selection starts','Selection ends']].astype(str)
#df['Selection starts'].str.split('m').str[0]

# %%
#Delete excess rows
df.dropna(axis=0,how="all",inplace=True)
#Create Datetimes
df[['Selection starts','Selection ends']]=df[['Selection starts','Selection ends']].apply(pd.to_datetime)
#Create Date Difference column
df['difference']=df['Selection ends']-df['Selection starts']
df['difference']=df['difference'].dt.seconds

# %% [markdown]
# ## Characters

# %%
ch_raw=pd.read_csv("characters.csv",encoding = "ISO-8859-1",sep=";")

# %%
ch=ch_raw.copy()

# %%
ch.head()
# Out:
#     Character Family         Actor  Description             Role  \
# 0      Ki Woo    Kim  Woo-sik Choi          NaN  English Teacher
# 1     Ki Jung    Kim   So-dam Park          NaN      Art Teacher
# 2     Ki Taek    Kim  Kang-ho Song          NaN        Chauffeur
# 3  Chung Sook    Kim  Hye-jin Jang          NaN      Housekeeper
# 4    Yeon Kyo   Park  Yeo-jeong Jo          NaN           Mother
#
#                                             urlImage
# 0  https://github.com/javiersgdtu/javiersgvisual/...
# 1  https://github.com/javiersgdtu/javiersgvisual/...
# 2  https://github.com/javiersgdtu/javiersgvisual/...
# 3  https://github.com/javiersgdtu/javiersgvisual/...
# 4  https://github.com/javiersgdtu/javiersgvisual/...

# %% [markdown]
# # Scenes

# %% [markdown]
# ## Preprocessing

# %%
#Filter Park House
df["location"].value_counts()
df_filt=df[df["location"]=="Park's House"]
df_filt["sublocation"]=df_filt["sublocation"].str.lower()
#Add the level field to the df_filt
df_filt.loc[df_filt["sublocation"].isin(["entrance-street","entrance-intercom","basement","garage","cave"]),"level"]="level0"
df_filt.loc[df_filt["sublocation"].isin(["entrance","kitchen","secondary garden","entrance-stairs","living room","garden","entrance-stairs garage"]),"level"]="level1"
df_filt.loc[df_filt["sublocation"].isin(["da hye's room","mr. & mrs. park room","da song's room","first floor-corridor","toilet","sauna room"]),"level"]="level2"
#df_filt[df_filt["level"].isna()] Chck evertyhing is good

#Add family field to the df_filt
df_filt=df_filt.merge(ch[["Character","Family"]],left_on="character",right_on="Character",how="left")
df_filt.loc[df_filt["character"].isin(["Moon Gwang","Geun Se"]),"Family"]="First"
df_filt.drop(["Character"],axis=1,inplace=True)
#df_filt.head()
# Out:
# C:\Users\Javier San Miguel\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ## General characters insights

# %%
#Get scene duration in Park House.
#This is the first time we use the merge_intervals function. There might be shorter ways of calculating it. I just wanted to
#use this method.
df_filt['dt_sub'] = df_filt[['Selection starts', 'Selection ends']].apply(tuple, axis=1) #Create a tuple (Date1,Date2)
#scene_selection = df_filt.groupby(["character"])['dt_sub'].apply(list)  #Create of all intervals grouped.
#scene_selection = df_filt.groupby(["Family"])['dt_sub'].apply(list)  #Create of all intervals grouped.
#scene_selection = df_filt.groupby(["Family","scene","level"])['dt_sub'].apply(list)  #Create of all intervals grouped.
scene_selection = df_filt.groupby(["character","sublocation"])['dt_sub'].apply(list)

f_scene_selection = scene_selection.apply(merge_intervals)   #Use above function to create a grouped list of min,max of each overlaped interval.

time_scene = pd.DataFrame(f_scene_selection.apply(lambda x: sum([(y[1]-y[0]).seconds for y in x])))
time_scene.reset_index(inplace=True)

# %%
time_gr=time_scene.groupby(['sublocation',"character"]).agg({'dt_sub': 'sum'})
# Change: groupby state_office and divide by sum
time_gr = time_gr.groupby(["sublocation"]).apply(lambda x:
                                                 100 * x / float(x.sum()))
time_gr.sort_values(["sublocation","dt_sub"],ascending=[False,False],inplace=True)

# %%
pd.set_option('display.max_rows', 100)

time_gr.tail(100)
# Out:
#                                             dt_sub
# sublocation            character
# living room            Yeon Kyo           8.037119
#                        Mr. Park           5.709343
#                        Moon Gwang         5.111670
#                        Geun Se            4.325260
#                        Da Hye             0.943693
#                        Da Song            0.707770
# kitchen                Yeon Kyo          32.454512
#                        Chung Sook        23.988117
#                        Ki Jung           10.397326
#                        Mr. Park           9.283327
#                        Ki Woo             6.981062
#                        Moon Gwang         6.349796
#                        Ki Taek            4.678797
#                        Da Song            3.230598
#                        Da Hye             1.633866
#                        Geun Se            1.002599
# garden                 Da Song           21.425097
#                        Party attendants  15.856031
#                        Ki Taek           14.567121
#                        Mr. Park          13.351167
#                        Yeon Kyo          10.919261
#                        Ki Jung           10.238327
#                        Chung Sook         6.517510
#                        Geun Se            3.137160
#                        Ki Woo             3.064202
#                        Moon Gwang         0.826848
#                        Da Hye             0.097276
# garage                 Ki Taek           15.873016
#                        Yeon Kyo          15.873016
#                        Chung Sook        14.285714
#                        Da Hye            11.111111
#                        Da Song           11.111111
#                        Ki Jung           11.111111
#                        Mr. Park          11.111111
#                        Ki Woo             9.523810
# first floor-corridor   Yeon Kyo          34.821429
#                        Da Hye            21.428571
#                        Ki Woo            19.642857
#                        Ki Jung            8.928571
#                        Chung Sook         8.035714
#                        Moon Gwang         5.357143
#                        Da Song            1.785714
# entrance-street        Moon Gwang        25.626741
#                        Ki Jung           25.348189
#                        Yeon Kyo          23.955432
#                        Ki Woo            15.041783
#                        Ki Taek            6.685237
#                        Party attendants   3.342618
# entrance-stairs garage Ki Jung           26.108374
#                        Ki Woo            26.108374
#                        Ki Taek           15.763547
#                        Yeon Kyo          12.807882
#                        Mr. Park          10.344828
#                        Da Hye             4.926108
#                        Da Song            1.970443
#                        First chaufer      1.970443
# entrance-stairs        Da Hye            34.806630
#                        Da Song           18.232044
#                        Ki Jung           18.232044
#                        Ki Woo             9.392265
#                        Ki Taek            6.629834
#                        Yeon Kyo           5.524862
#                        Mr. Park           4.972376
#                        Chung Sook         2.209945
# entrance-intercom      Moon Gwang        34.909091
#                        Ki Woo            31.272727
#                        Ki Jung           17.454545
#                        Yeon Kyo          16.363636
# entrance               Chung Sook        25.937500
#                        Yeon Kyo          19.687500
#                        Ki Woo            17.031250
#                        Moon Gwang        13.281250
#                        Ki Jung            5.781250
#                        Mr. Park           5.000000
#                        First chaufer      4.062500
#                        Da Song            3.750000
#                        Ki Taek            3.750000
#                        Da Hye             1.718750
# da song's room         Da Song           37.878788
#                        Ki Jung           37.878788
#                        Yeon Kyo          15.151515
#                        Chung Sook         9.090909
# da hye's room          Ki Woo            47.746244
#                        Da Hye            46.243740
#                        Yeon Kyo           4.841402
#                        Moon Gwang         0.723428
#                        Chung Sook         0.445186
# cave                   Geun Se           27.364680
#                        Moon Gwang        23.127392
#                        Ki Taek           22.279934
#                        Ki Woo            10.907600
#                        Chung Sook         9.103335
#                        Ki Jung            7.217059
# basement               Ki Woo            24.908425
#                        Moon Gwang        21.978022
#                        Ki Taek           21.245421
#                        Chung Sook        13.736264
#                        Geun Se           10.805861
#                        Yeon Kyo           5.494505
#                        Ki Jung            1.831502

# %% [markdown]
# ### Evolution of ocupation by family of House levels.

# %%
#Evolution of ocupation by family of House levels.

#and above.
#scene_selection = df_filt.groupby(["Family","scene","level"])['dt_sub'].apply(list)  #Create of all intervals grouped.

time_gr=time_scene.groupby(["scene",'level',"Family"]).agg({'dt_sub': 'sum'})
# Change: groupby state_office and divide by sum
time_gr = time_gr.groupby(["scene","level"]).apply(lambda x:
                                                 100 * x / float(x.sum()))
time_gr
# Out:
#                          dt_sub
# scene level  Family
# 3.0   level0 Kim      73.118280
#              Park     26.881720
#       level1 First    24.000000
#              Kim      41.935484
#              Park     34.064516
#       level2 Kim      47.761194
#              Park     52.238806
# 4.0   level0 First    42.424242
#              Kim      33.333333
#              Park     24.242424
#       level1 First    13.780261
#              Kim      41.340782
#              Park     44.878957
#       level2 Kim      50.000000
#              Park     50.000000
# 5.0   level0 First    27.611940
#              Kim      37.313433
#              Park     35.074627
#       level1 Kim      21.343874
#              Park     78.656126
# 6.0   level0 First    52.941176
#              Kim      29.411765
#              Park     17.647059
#       level1 First    32.142857
#              Kim      35.000000
#              Park     32.857143
#       level2 First     6.209150
#              Kim      47.712418
#              Park     46.078431
# 7.0   level0 Kim      53.333333
#              Park     46.666667
#       level1 Kim      85.576923
#              Park     14.423077
#       level2 Kim      91.304348
#              Park      8.695652
# 8.0   level0 First    50.791917
#              Kim      49.208083
#       level1 First    13.467294
#              Kim      56.092347
#              Park     30.440359
#       level2 Kim      50.173812
#              Park     49.826188
# 9.0   level0 First    54.862385
#              Kim      42.935780
#              Park      2.201835
#       level1 First    10.600945
#              Kim      40.783255
#              Park     48.615800
#       level2 Kim      38.403042
#              Park     61.596958
# 10.0  level0 Kim     100.000000
#       level1 Kim     100.000000

# %%
time_gr.sort_values(["level","scene","dt_sub"],ascending=[False,True,False])
time_gr.reset_index(inplace=True)
fig=sns.relplot(x="scene", y="dt_sub", hue="Family",
            col="level", height=3,
            kind="line", estimator=None, data=time_gr);

# %% [markdown]
# ## Force layout

# %% [markdown]
# There are 3 main variables displayed in the force layout: Character,Duration in each sublocation & movement in this scene

# %%
#All the duration of characters in the same scene+sublocation should be grouped.
df_gr=df_filt.groupby(["scene","character","sublocation"],as_index=False).agg({"difference":"sum","Movement":lambda x: ','.join(x)})

#Remove duplicates of column Movement after concatenation
#df_gr["Movement"]=[','.join(set(j["Movement"].split(','))) for i,j in df_gr.iterrows()] //alphabetical order
df_gr["Movement"]=[",".join(OrderedDict.fromkeys(j["Movement"].split(','))) for i,j in df_gr.iterrows()]

# %%
df_gr.head(15)
# Out:
#     scene   character           sublocation  difference      Movement
# 0     3.0      Da Hye         da hye's room          87        Static
# 1     3.0     Da Song              entrance          17          Move
# 2     3.0     Da Song       entrance-stairs           9          Down
# 3     3.0     Da Song                garden          34          Move
# 4     3.0     Da Song           living room          35          Move
# 5     3.0      Ki Woo         da hye's room          87        Static
# 6     3.0      Ki Woo              entrance          94     Move,Down
# 7     3.0      Ki Woo     entrance-intercom          43  Up,Move,Down
# 8     3.0      Ki Woo       entrance-stairs           8            Up
# 9     3.0      Ki Woo       entrance-street          25  Move,Up,Down
# 10    3.0      Ki Woo  first floor-corridor           9          Move
# 11    3.0      Ki Woo               kitchen         132   Move,Static
# 12    3.0      Ki Woo           living room          91   Static,Move
# 13    3.0  Moon Gwang              entrance          50          Move
# 14    3.0  Moon Gwang                garden          34          Move

# %%
df_gr.head(50)
print(df_gr.dtypes)
df_gr.difference.describe()
# Out:
# scene          float64
# character       object
# sublocation     object
# difference       int64
# Movement        object
# dtype: object
# count     248.000000
# mean       87.060484
# std       164.295405
# min         1.000000
# 25%         9.000000
# 50%        22.000000
# 75%        74.000000
# max      1110.000000
# Name: difference, dtype: float64

# %%
#replace some characters to match the name of the center elements in the svg
df_gr["sublocation"].replace(" ",'_',regex=True,inplace=True)
df_gr["sublocation"].replace('&','',regex=True,inplace=True)
df_gr["sublocation"].replace('\\._','_',regex=True,inplace=True)
df_gr["sublocation"].replace("'",'_',regex=True,inplace=True)

# %%
#Get scene duration in Park House.
#This is the first time we use the merge_intervals function. There might be shorter ways of calculating it. I just wanted to
#use this method.
df_filt['dt_sub'] = df_filt[['Selection starts', 'Selection ends']].apply(tuple, axis=1) #Create a tuple (Date1,Date2)
scene_selection = df_filt.groupby(["scene"])['dt_sub'].apply(list)  #Create of all intervals grouped.
f_scene_selection = scene_selection.apply(merge_intervals)   #Use above function to create a grouped list of min,max of each overlaped interval.

time_scene = pd.DataFrame(f_scene_selection.apply(lambda x: sum([(y[1]-y[0]).seconds for y in x])))
time_scene.reset_index(inplace=True)

# %%
#check=df_filt[df_filt["sublocation"].isin(["garden","entrance","basement"])]
df_gr=df_gr[~df_gr["sublocation"].isin(["toilet","sauna_room"])]#,"entrance-intercom"
df_gr.sublocation.value_counts()
# Out:
# kitchen                   35
# living_room               29
# entrance                  29
# garden                    23
# entrance-stairs           18
# entrance-stairs_garage    15
# da_hye_s_room             14
# basement                  13
# entrance-street           13
# garage                    11
# first_floor-corridor      11
# cave                      10
# entrance-intercom          8
# da_song_s_room             6
# secondary_garden           4
# mr__mrs_park_room          4
# Name: sublocation, dtype: int64

# %%
#Merge df_gr with time_scene.
df_gr=time_scene.merge(df_gr,on="scene")

# %%
df_gr.to_json("data_out/scenes.json",orient='records');
#check.to_json("data_out/scenes.json",orient='records');

# %%
time_scene.to_json("data_out/time_scene.json",orient='records');

# %% [markdown]
# ## Movement insights

# %% [markdown]
#  Interesting analysis to address:
#  * See what family moves the most up/down (UP and down) and who is more static
#  * Character the longest in the film
#  * Sevice woman
#  * Character the longest static
#  * Who occupies the lower and upper floors the most

# %%
df_filt["Movement"]=df_filt["Movement"].str.lower()

# %%
#Filter specific movement
df_move= df_filt[df_filt["Movement"].str.contains("static")]#down,static,move
df_move=df_move.groupby(["scene","character"],as_index=False).agg({"difference":"sum"})
#df_move=df_move.groupby(["scene","Family"],as_index=False).agg({"difference":"sum"})
df_move.rename({"difference":"move_time"},axis=1,inplace=True)

#How much time does every character appears in a scene:
df_character_scene=df_filt.groupby(["scene","character"],as_index=False).agg({"difference":"sum"})
#df_character_scene=df_filt.groupby(["scene","Family"],as_index=False).agg({"difference":"sum"})
df_character_scene.rename({"difference":"scene_time"},axis=1,inplace=True)

df_move_mg=df_move.merge(df_character_scene,on=["scene","character"],how="right")
#df_move_mg=df_move.merge(df_character_scene,on=["scene","Family"],how="right")

df_move_mg.fillna(0,inplace=True)
df_move_mg["pct"] = np.round(100*(df_move_mg["move_time"] / df_move_mg["scene_time"]),1)
df_move_mg.sort_values(["scene","move_time"],ascending=[True,False],inplace=True)
# To see how much time per scene a character is moving in a specific direction.
df_move_mg
# Out:
#     scene         character  move_time  scene_time    pct
# 1     3.0            Ki Woo      310.0         489   63.4
# 2     3.0          Yeon Kyo      309.0         394   78.4
# 0     3.0            Da Hye       87.0          87  100.0
# 50    3.0           Da Song        0.0          95    0.0
# 51    3.0        Moon Gwang        0.0         186    0.0
# 6     4.0            Ki Woo      249.0         271   91.9
# 3     4.0            Da Hye      247.0         247  100.0
# 5     4.0           Ki Jung      222.0         272   81.6
# 7     4.0          Yeon Kyo      210.0         285   73.7
# 4     4.0           Da Song       46.0          63   73.0
# 52    4.0     First chaufer        0.0          30    0.0
# 53    4.0        Moon Gwang        0.0         102    0.0
# 54    4.0          Mr. Park        0.0          32    0.0
# 11    5.0          Yeon Kyo      250.0         293   85.3
# 10    5.0          Mr. Park      166.0         176   94.3
# 9     5.0        Moon Gwang       74.0          74  100.0
# 8     5.0           Ki Jung       27.0         154   17.5
# 19    6.0          Yeon Kyo      124.0         172   72.1
# 15    6.0           Ki Taek       74.0         139   53.2
# 17    6.0        Moon Gwang       60.0         127   47.2
# 13    6.0           Da Song       36.0          36  100.0
# 14    6.0           Ki Jung       32.0          58   55.2
# 12    6.0            Da Hye       31.0          31  100.0
# 16    6.0            Ki Woo       31.0          44   70.5
# 18    6.0          Mr. Park        6.0           6  100.0
# 55    6.0        Chung Sook        0.0          33    0.0
# 25    7.0            Ki Woo      570.0         586   97.3
# 24    7.0           Ki Taek      559.0         603   92.7
# 23    7.0           Ki Jung      536.0         536  100.0
# 20    7.0        Chung Sook      422.0         504   83.7
# 21    7.0            Da Hye       58.0          72   80.6
# 22    7.0           Da Song       58.0         107   54.2
# 26    7.0          Mr. Park       58.0         112   51.8
# 27    7.0          Yeon Kyo       28.0         100   28.0
# 35    8.0        Moon Gwang     1025.0        1239   82.7
# 31    8.0           Geun Se     1019.0        1035   98.5
# 37    8.0          Yeon Kyo      628.0         710   88.5
# 33    8.0           Ki Taek      456.0        1445   31.6
# 29    8.0            Da Hye      453.0         507   89.3
# 28    8.0        Chung Sook      381.0        1399   27.2
# 36    8.0          Mr. Park      328.0         394   83.2
# 32    8.0           Ki Jung      184.0        1456   12.6
# 34    8.0            Ki Woo      184.0        1429   12.9
# 30    8.0           Da Song      146.0         167   87.4
# 39    9.0           Da Song      672.0         672  100.0
# 46    9.0  Party attendants      652.0         664   98.2
# 42    9.0           Ki Taek      551.0         567   97.2
# 45    9.0          Mr. Park      539.0         553   97.5
# 41    9.0           Ki Jung      411.0         480   85.6
# 40    9.0           Geun Se      269.0         456   59.0
# 44    9.0        Moon Gwang      104.0         104  100.0
# 38    9.0            Da Hye      101.0         157   64.3
# 43    9.0            Ki Woo      101.0         345   29.3
# 47    9.0          Yeon Kyo       61.0         557   11.0
# 56    9.0        Chung Sook        0.0         260    0.0
# 48   10.0           Ki Taek       92.0         293   31.4
# 49   10.0            Ki Woo       21.0         107   19.6
# 57   10.0        Chung Sook        0.0          79    0.0

# %%
df_character_scene.head(10)

# %%
df_move_mg.sort_values(["scene","pct"],ascending=[True,False],inplace=True)
df_move_mg
# Out:
#     scene         character  move_time  scene_time    pct
# 0     3.0            Da Hye       87.0          87  100.0
# 2     3.0          Yeon Kyo      309.0         394   78.4
# 1     3.0            Ki Woo      310.0         489   63.4
# 50    3.0           Da Song        0.0          95    0.0
# 51    3.0        Moon Gwang        0.0         186    0.0
# 3     4.0            Da Hye      247.0         247  100.0
# 6     4.0            Ki Woo      249.0         271   91.9
# 5     4.0           Ki Jung      222.0         272   81.6
# 7     4.0          Yeon Kyo      210.0         285   73.7
# 4     4.0           Da Song       46.0          63   73.0
# 52    4.0     First chaufer        0.0          30    0.0
# 53    4.0        Moon Gwang        0.0         102    0.0
# 54    4.0          Mr. Park        0.0          32    0.0
# 9     5.0        Moon Gwang       74.0          74  100.0
# 10    5.0          Mr. Park      166.0         176   94.3
# 11    5.0          Yeon Kyo      250.0         293   85.3
# 8     5.0           Ki Jung       27.0         154   17.5
# 13    6.0           Da Song       36.0          36  100.0
# 12    6.0            Da Hye       31.0          31  100.0
# 18    6.0          Mr. Park        6.0           6  100.0
# 19    6.0          Yeon Kyo      124.0         172   72.1
# 16    6.0            Ki Woo       31.0          44   70.5
# 14    6.0           Ki Jung       32.0          58   55.2
# 15    6.0           Ki Taek       74.0         139   53.2
# 17    6.0        Moon Gwang       60.0         127   47.2
# 55    6.0        Chung Sook        0.0          33    0.0
# 23    7.0           Ki Jung      536.0         536  100.0
# 25    7.0            Ki Woo      570.0         586   97.3
# 24    7.0           Ki Taek      559.0         603   92.7
# 20    7.0        Chung Sook      422.0         504   83.7
# 21    7.0            Da Hye       58.0          72   80.6
# 22    7.0           Da Song       58.0         107   54.2
# 26    7.0          Mr. Park       58.0         112   51.8
# 27    7.0          Yeon Kyo       28.0         100   28.0
# 31    8.0           Geun Se     1019.0        1035   98.5
# 29    8.0            Da Hye      453.0         507   89.3
# 37    8.0          Yeon Kyo      628.0         710   88.5
# 30    8.0           Da Song      146.0         167   87.4
# 36    8.0          Mr. Park      328.0         394   83.2
# 35    8.0        Moon Gwang     1025.0        1239   82.7
# 33    8.0           Ki Taek      456.0        1445   31.6
# 28    8.0        Chung Sook      381.0        1399   27.2
# 34    8.0            Ki Woo      184.0        1429   12.9
# 32    8.0           Ki Jung      184.0        1456   12.6
# 39    9.0           Da Song      672.0         672  100.0
# 44    9.0        Moon Gwang      104.0         104  100.0
# 46    9.0  Party attendants      652.0         664   98.2
# 45    9.0          Mr. Park      539.0         553   97.5
# 42    9.0           Ki Taek      551.0         567   97.2
# 41    9.0           Ki Jung      411.0         480   85.6
# 38    9.0            Da Hye      101.0         157   64.3
# 40    9.0           Geun Se      269.0         456   59.0
# 43    9.0            Ki Woo      101.0         345   29.3
# 47    9.0          Yeon Kyo       61.0         557   11.0
# 56    9.0        Chung Sook        0.0         260    0.0
# 48   10.0           Ki Taek       92.0         293   31.4
# 49   10.0            Ki Woo       21.0         107   19.6
# 57   10.0        Chung Sook        0.0          79    0.0

# %%
#Across the film.
df_move_film=df_move_mg.groupby("character",as_index=False).agg({"move_time":"sum","scene_time":"sum"})
#df_move_film=df_move_mg.groupby("Family",as_index=False).agg({"move_time":"sum","scene_time":"sum"})

df_move_film["pct"] = np.round(100*(df_move_film["move_time"] / df_move_film["scene_time"]),1)
df_move_film.sort_values(["move_time"],ascending=False,inplace=True)
df_move_film
# Out:
#            character  move_time  scene_time   pct
# 6            Ki Taek     1732.0        3047  56.8
# 11          Yeon Kyo     1610.0        2511  64.1
# 7             Ki Woo     1466.0        3271  44.8
# 5            Ki Jung     1412.0        2956  47.8
# 4            Geun Se     1288.0        1491  86.4
# 8         Moon Gwang     1263.0        1832  68.9
# 9           Mr. Park     1097.0        1273  86.2
# 1             Da Hye      977.0        1101  88.7
# 2            Da Song      958.0        1140  84.0
# 0         Chung Sook      803.0        2275  35.3
# 10  Party attendants      652.0         664  98.2
# 3      First chaufer        0.0          30   0.0

# %%
df_move_film.sort_values(["pct"],ascending=False,inplace=True)
df_move_film
# Out:
#            character  move_time  scene_time   pct
# 10  Party attendants      652.0         664  98.2
# 1             Da Hye      977.0        1101  88.7
# 4            Geun Se     1288.0        1491  86.4
# 9           Mr. Park     1097.0        1273  86.2
# 2            Da Song      958.0        1140  84.0
# 8         Moon Gwang     1263.0        1832  68.9
# 11          Yeon Kyo     1610.0        2511  64.1
# 6            Ki Taek     1732.0        3047  56.8
# 5            Ki Jung     1412.0        2956  47.8
# 7             Ki Woo     1466.0        3271  44.8
# 0         Chung Sook      803.0        2275  35.3
# 3      First chaufer        0.0          30   0.0

# %% [markdown]
# ## Movement Viz

# %%
#All the duration of characters in the same scene+sublocation should be grouped.
df_filt["Movement"]=df_filt["Movement"].str.lower()
#Get duration in each scene & level /character.
df_gr=df_filt.groupby(["scene","character","level","Family"],as_index=False).agg({"difference":"sum"})
df_gr.rename({"difference":"scene_level_time"},axis=1,inplace=True)

# %%
#Explode=separate string Movement into rows.
df_explo=df_filt.assign(Movement_dup=df_filt['Movement'].str.split(',')).explode('Movement_dup')
df_explo.rename({"difference":"move_time"},axis=1,inplace=True)
#Classify column
df_explo["Movement_class"]=df_explo["Movement_dup"]
df_explo.loc[df_explo["Movement_dup"].isin(["up","down"]),"Movement_class"]="up|down"
#group scenes,level,character & movement dup. There can be characters with
#several same moves per scene/level that need to be grouped
df_explo=df_explo.groupby(["scene","character","level","Movement_dup"],as_index=False).agg({"move_time":"sum","Movement_class":"first"})
df_explo=df_explo.groupby(["scene","character","level","Movement_class"],as_index=False).agg({"move_time":"first"})

# %%
#groupby to see time going up down per level,sublocation, character
df_mg=df_gr.merge(df_explo,on=["scene","character","level"])

df_mg["pct"] = np.round(100*(df_mg["move_time"] / df_mg["scene_level_time"]),1)
#df_mg.sort_values(["scene","level","Movement_dup","pct"],ascending=[True,True,True,False],inplace=True)
df_mg.sort_values(["scene","level","Movement_class","pct"],ascending=[True,True,True,False],inplace=True)

# %%
df_mg.head(30)
# Out:
#     scene   character   level Family  scene_level_time Movement_class  \
# 11    3.0    Yeon Kyo  level0   Park                25           move
# 3     3.0      Ki Woo  level0    Kim                68           move
# 12    3.0    Yeon Kyo  level0   Park                25        up|down
# 4     3.0      Ki Woo  level0    Kim                68        up|down
# 10    3.0  Moon Gwang  level1  First               186           move
# 1     3.0     Da Song  level1   Park                95           move
# 5     3.0      Ki Woo  level1    Kim               325           move
# 13    3.0    Yeon Kyo  level1   Park               264           move
# 14    3.0    Yeon Kyo  level1   Park               264         static
# 6     3.0      Ki Woo  level1    Kim               325         static
# 15    3.0    Yeon Kyo  level1   Park               264        up|down
# 7     3.0      Ki Woo  level1    Kim               325        up|down
# 2     3.0     Da Song  level1   Park                95        up|down
# 8     3.0      Ki Woo  level2    Kim                96           move
# 16    3.0    Yeon Kyo  level2   Park               105           move
# 0     3.0      Da Hye  level2   Park                87         static
# 17    3.0    Yeon Kyo  level2   Park               105         static
# 9     3.0      Ki Woo  level2    Kim                96         static
# 33    4.0  Moon Gwang  level0  First                28           move
# 38    4.0    Yeon Kyo  level0   Park                16           move
# 25    4.0     Ki Jung  level0    Kim                22        up|down
# 28    4.0      Ki Woo  level0    Kim                22        up|down
# 34    4.0  Moon Gwang  level0  First                28        up|down
# 39    4.0    Yeon Kyo  level0   Park                16        up|down
# 29    4.0      Ki Woo  level1    Kim                43           move
# 35    4.0  Moon Gwang  level1  First                74           move
# 36    4.0    Mr. Park  level1   Park                32           move
# 40    4.0    Yeon Kyo  level1   Park               241           move
# 21    4.0     Da Song  level1   Park                43           move
# 18    4.0      Da Hye  level1   Park                41         static
#
#     move_time    pct
# 11         25  100.0
# 3          40   58.8
# 12         25  100.0
# 4          25   36.8
# 10        186  100.0
# 1          86   90.5
# 5         288   88.6
# 13        134   50.8
# 14        213   80.7
# 6         223   68.6
# 15         43   16.3
# 7          43   13.2
# 2           9    9.5
# 8           9    9.4
# 16          9    8.6
# 0          87  100.0
# 17         96   91.4
# 9          87   90.6
# 33         28  100.0
# 38         16  100.0
# 25         22  100.0
# 28         22  100.0
# 34         28  100.0
# 39         16  100.0
# 29         43  100.0
# 35         74  100.0
# 36         24   75.0
# 40        179   74.3
# 21         26   60.5
# 18         41  100.0

# %%
#df_mg_ft=df_mg[df_mg["Movement_dup"]!="hiding"]
df_mg_ft=df_mg[df_mg["Movement_class"]!="hiding"]

df_mg_ft=df_mg_ft[~df_mg_ft["character"].isin(["Party attendants","First chaufer"])]

fig=sns.relplot(x="scene", y="pct", hue="Family",
            col="level", row="Movement_class", height=3,
            kind="line", estimator=None, data=df_mg_ft);

# %%
fig.savefig('C:/Users/Javier San Miguel/Desktop/Data/Data visualization/Parasite/doc/img/familymovementline.png',dpi=200)

# %% [markdown]
# ### Insights from Viz

# %%
df_mg.head(20)
# Out:
#     scene   character   level Family  scene_level_time Movement_class  \
# 11    3.0    Yeon Kyo  level0   Park                25           move
# 3     3.0      Ki Woo  level0    Kim                68           move
# 12    3.0    Yeon Kyo  level0   Park                25        up|down
# 4     3.0      Ki Woo  level0    Kim                68        up|down
# 10    3.0  Moon Gwang  level1  First               186           move
# 1     3.0     Da Song  level1   Park                95           move
# 5     3.0      Ki Woo  level1    Kim               325           move
# 13    3.0    Yeon Kyo  level1   Park               264           move
# 14    3.0    Yeon Kyo  level1   Park               264         static
# 6     3.0      Ki Woo  level1    Kim               325         static
# 15    3.0    Yeon Kyo  level1   Park               264        up|down
# 7     3.0      Ki Woo  level1    Kim               325        up|down
# 2     3.0     Da Song  level1   Park                95        up|down
# 8     3.0      Ki Woo  level2    Kim                96           move
# 16    3.0    Yeon Kyo  level2   Park               105           move
# 0     3.0      Da Hye  level2   Park                87         static
# 17    3.0    Yeon Kyo  level2   Park               105         static
# 9     3.0      Ki Woo  level2    Kim                96         static
# 33    4.0  Moon Gwang  level0  First                28           move
# 38    4.0    Yeon Kyo  level0   Park                16           move
#
#     move_time    pct
# 11         25  100.0
# 3          40   58.8
# 12         25  100.0
# 4          25   36.8
# 10        186  100.0
# 1          86   90.5
# 5         288   88.6
# 13        134   50.8
# 14        213   80.7
# 6         223   68.6
# 15         43   16.3
# 7          43   13.2
# 2           9    9.5
# 8           9    9.4
# 16          9    8.6
# 0          87  100.0
# 17         96   91.4
# 9          87   90.6
# 33         28  100.0
# 38         16  100.0

# %%
df_mg[df_mg.pct>50]
#groupby(["scene","level","Movement_class"]).#filter(lambda x: (x['pct'] > 50).any())
#["pct"].agg({"pct":"first","character":"first","Family":"first"})
# Out:
#      scene   character   level Family  scene_level_time Movement_class  \
# 11     3.0    Yeon Kyo  level0   Park                25           move
# 3      3.0      Ki Woo  level0    Kim                68           move
# 12     3.0    Yeon Kyo  level0   Park                25        up|down
# 10     3.0  Moon Gwang  level1  First               186           move
# 1      3.0     Da Song  level1   Park                95           move
# ..     ...         ...     ...    ...               ...            ...
# 208   10.0     Ki Taek  level0    Kim               175         static
# 214   10.0      Ki Woo  level0    Kim                28        up|down
# 206   10.0  Chung Sook  level1    Kim                79           move
# 215   10.0      Ki Woo  level1    Kim                79           move
# 210   10.0     Ki Taek  level1    Kim               118           move
#
#      move_time    pct
# 11          25  100.0
# 3           40   58.8
# 12          25  100.0
# 10         186  100.0
# 1           86   90.5
# ..         ...    ...
# 208         92   52.6
# 214         28  100.0
# 206         79  100.0
# 215         79  100.0
# 210        108   91.5
#
# [167 rows x 8 columns]

# %%
result=pd.DataFrame(grouped.apply(
    lambda x:  x['pct'] - x['pct'].shift()>20))

# %%
result
# Out:
#                                    pct
# scene level  Movement_class
# 3.0   level0 move           11   False
#                             3    False
#              up|down        12   False
#                             4    False
#       level1 move           10   False
# ...                                ...
# 10.0  level0 up|down        209  False
#       level1 move           206  False
#                             215  False
#                             210  False
#              up|down        211  False
#
# [216 rows x 1 columns]

# %% [markdown]
# # Locations in the film

# %% [markdown]
# Due to the DB schema there are moments in the film where characters are in different locations and counted in both of them. Though the Date of an opening character in a scene and the closing one are the first and last moments in which the location appears.

# %%
df_loc=df.copy()
df_loc.head(10)
# Out:
#    scene                   description     location  sublocation character  \
# 0    0.0               initial Credits          NaN          NaN       NaN
# 1    1.0  Family Introduction -No Wifi  Kim's House  Living room    Ki Woo
# 2    1.0  Family Introduction -No Wifi  Kim's House     Corridor    Ki Woo
# 3    1.0         Ki Taek quicks insect  Kim's House  Living room    Ki Woo
# 4    1.0                           NaN  Kim's House     Corridor    Ki Woo
# 5    1.0            Wifi in the toilet  Kim's House     Bathroom    Ki Woo
# 6    1.0            Wifi in the toilet  Kim's House     Corridor    Ki Woo
# 7    1.0  Family Introduction -No Wifi  Kim's House     Bathroom   Ki Jung
# 8    1.0  Family Introduction -No Wifi  Kim's House     Corridor   Ki Jung
# 9    1.0  Family Introduction -No Wifi  Kim's House       Room I   Ki Jung
#
#      Selection starts      Selection ends    Diff. State Movement Note  \
# 0 2020-11-16 00:00:00 2020-11-16 00:00:45  0:00:45   NaN      NaN  NaN
# 1 2020-11-16 00:00:45 2020-11-16 00:01:40  0:00:55   NaN      NaN  NaN
# 2 2020-11-16 00:01:40 2020-11-16 00:02:10  0:00:30   NaN      NaN  NaN
# 3 2020-11-16 00:02:14 2020-11-16 00:02:20  0:00:06   NaN      NaN  NaN
# 4 2020-11-16 00:02:20 2020-11-16 00:02:24  0:00:04   NaN      NaN  NaN
# 5 2020-11-16 00:02:34 2020-11-16 00:03:03  0:00:29   NaN      NaN  NaN
# 6 2020-11-16 00:03:03 2020-11-16 00:03:06  0:00:03   NaN      NaN  NaN
# 7 2020-11-16 00:00:45 2020-11-16 00:01:42  0:00:57   NaN      NaN  NaN
# 8 2020-11-16 00:01:42 2020-11-16 00:01:46  0:00:04   NaN      NaN  NaN
# 9 2020-11-16 00:01:46 2020-11-16 00:02:10  0:00:24   NaN      NaN  NaN
#
#    difference
# 0          45
# 1          55
# 2          30
# 3           6
# 4           4
# 5          29
# 6           3
# 7          57
# 8           4
# 9          24

# %%
#Second method. Without locationid
df_loc['dt'] = df_loc[['Selection starts', 'Selection ends']].apply(tuple, axis=1) #Create a tuple (Date1,Date2)
list_selection = df_loc.groupby(["location"])['dt'].apply(list)  #Create of all intervals grouped.
f_list_selection = list_selection.apply(merge_intervals)   #Use above function to create a grouped list of min,max of each overlaped interval.

time_locat = pd.DataFrame(f_list_selection.apply(lambda x: sum([(y[1]-y[0]).seconds for y in x])))
time_locat.reset_index(inplace=True)

# %%
time_loc=time_locat.groupby("location").agg({"dt":"sum"})
time_loc["pct"] = time_loc.apply(lambda x:np.round(100 * x / x.sum(),1))
#time_loc
time_loc=time_loc.reset_index().sort_values("pct",ascending=False)
time_loc
# Out:
#                  location    dt   pct
# 12           Park's House  5259  65.8
# 9             Kim's House   884  11.1
# 11          Mr.Park's car   477   6.0
# 17                Stadium   245   3.1
# 18  Street by Kim's house   224   2.8
# 6            Grocery shop   181   2.3
# 15          Seoul streets   173   2.2
# 10       Mr's Park Office   145   1.8
# 7                Hospital    83   1.0
# 16          Shopping Mall    73   0.9
# 1       Buffet restaurant    70   0.9
# 5                  Forest    57   0.7
# 0       Authorised Dealer    23   0.3
# 8           Internet Café    24   0.3
# 19                 Subway    20   0.3
# 13            Pizza place    12   0.2
# 4                   Court    12   0.2
# 3               Cementery    17   0.2
# 14                  River     7   0.1
# 2                     Bus     7   0.1

# %%
#Grouping similar numbers.
time_loc.loc[~time_loc.location.isin(["Park's House","Kim's House","Mr.Park's car","Street by Kim's house","Stadium"]),"location"]="Other Seoul locations"
time_loc.loc[time_loc.location.isin(["Kim's House","Street by Kim's house"]),"location"]="Kim's House"

# %%
time_loc=time_loc.groupby("location",as_index=True).agg({"pct":"sum"})
time_loc
# Out:
#                         pct
# location
# Kim's House            13.9
# Mr.Park's car           6.0
# Other Seoul locations  11.5
# Park's House           65.8
# Stadium                 3.1

# %% [markdown]
# ## Sublocations in Park House

# %%
df_loc_filt=df_filt.copy()
#df_loc_filt=df[df["location"]=="Park's House"]
df_loc_filt_dup=df_loc_filt.copy()

# %%
#The dataset created locates each character in the point that they are staying
#(when this information is provided) rather than their time in screen.
df_loc_filt_dup.sort_values("difference",ascending=False).head(20)
# Out:
#      scene                                        description      location  \
# 203    8.0              Kim family attack + peach inoculation  Park's House
# 300    9.0                   Kevin and Da Hye: Do i fit here?  Park's House
# 301    9.0                   Kevin and Da Hye: Do i fit here?  Park's House
# 304    9.0         Dressing as indians to surprise to Da Song  Park's House
# 169    7.0                            Drinking+ someone calls  Park's House
# 168    7.0                            Drinking+ someone calls  Park's House
# 170    7.0                            Drinking+ someone calls  Park's House
# 305    9.0         Dressing as indians to surprise to Da Song  Park's House
# 213    8.0  Preparing Ram Don + locking Geun Se and Moon G...  Park's House
# 225    8.0  Bringing back diary to Da Hye + hiding in her ...  Park's House
# 318    9.0                                   Birthday "party"  Park's House
# 317    9.0                                   Birthday "party"  Park's House
# 226    8.0                      Bringing back diary to Da Hye  Park's House
# 249    8.0  Hiding in the living room+Da song camps in garden  Park's House
# 167    7.0                            Drinking+ someone calls  Park's House
# 183    8.0                        The  basement's secret door  Park's House
# 248    8.0  Hiding in the living room+Da song camps in garden  Park's House
# 266    8.0                Hiding in the living room+sex scene  Park's House
# 186    8.0  Discovering the "parasite"+ Kim's family fall+...  Park's House
# 267    8.0                Hiding in the living room+sex scene  Park's House
#
#        sublocation         character    Selection starts      Selection ends  \
# 203    living room           Ki Jung 2020-11-16 01:15:11 2020-11-16 01:30:52
# 300         garden  Party attendants 2020-11-16 01:45:09 2020-11-16 01:56:01
# 301         garden           Da Song 2020-11-16 01:45:09 2020-11-16 01:56:01
# 304         garden           Ki Taek 2020-11-16 01:46:50 2020-11-16 01:56:01
# 169    living room            Ki Woo 2020-11-16 00:56:31 2020-11-16 01:05:07
# 168    living room           Ki Taek 2020-11-16 00:56:31 2020-11-16 01:05:07
# 170    living room           Ki Jung 2020-11-16 00:56:31 2020-11-16 01:05:07
# 305         garden          Mr. Park 2020-11-16 01:46:50 2020-11-16 01:55:10
# 213           cave           Geun Se 2020-11-16 01:16:54 2020-11-16 01:24:14
# 225  da hye's room            Ki Woo 2020-11-16 01:17:53 2020-11-16 01:24:55
# 318         garden           Ki Jung 2020-11-16 01:49:10 2020-11-16 01:56:01
# 317         garden          Yeon Kyo 2020-11-16 01:49:10 2020-11-16 01:56:01
# 226  da hye's room            Da Hye 2020-11-16 01:17:56 2020-11-16 01:24:42
# 249    living room           Ki Taek 2020-11-16 01:25:17 2020-11-16 01:31:44
# 167    living room        Chung Sook 2020-11-16 00:56:31 2020-11-16 01:02:46
# 183           cave        Moon Gwang 2020-11-16 01:06:28 2020-11-16 01:12:08
# 248    living room            Ki Woo 2020-11-16 01:25:17 2020-11-16 01:30:53
# 266    living room          Yeon Kyo 2020-11-16 01:26:14 2020-11-16 01:31:48
# 186           cave        Chung Sook 2020-11-16 01:06:35 2020-11-16 01:12:08
# 267    living room          Mr. Park 2020-11-16 01:26:20 2020-11-16 01:31:48
#
#        Diff.                                              State  \
# 203  0:15:41                                                NaN
# 300  0:10:52                                                NaN
# 301  0:10:52             We don't see him but know he is there.
# 304  0:09:11                                                NaN
# 169  0:08:36                                                NaN
# 168  0:08:36                                                NaN
# 170  0:08:36                                                NaN
# 305  0:08:20                                              death
# 213  0:07:20  When Ki Taek leaves the cave. 1:49:21 till las...
# 225  0:07:02                                                NaN
# 318  0:06:51                                              death
# 317  0:06:51                                                NaN
# 226  0:06:46                                                NaN
# 249  0:06:27                                                NaN
# 167  0:06:15                                                NaN
# 183  0:05:40                                                NaN
# 248  0:05:36                                                NaN
# 266  0:05:34  when the Kim's enter in the garage. They are i...
# 186  0:05:33                                                NaN
# 267  0:05:28  when the Kim's enter in the garage. They are i...
#
#              Movement Note  difference   level Family
# 203       Move,Hiding  NaN         941  level1    Kim
# 300       Move,Static  NaN         652  level1    NaN
# 301       Static,Move  NaN         652  level1   Park
# 304       Static,Move  NaN         551  level1    Kim
# 169            Static  NaN         516  level1    Kim
# 168            Static  NaN         516  level1    Kim
# 170            Static  NaN         516  level1    Kim
# 305       Static,Move  NaN         500  level1   Park
# 213  Down,Move,Static  NaN         440  level0  First
# 225       Move,Hiding  NaN         422  level2    Kim
# 318       Move,Static  NaN         411  level1    Kim
# 317              Move  NaN         411  level1   Park
# 226       Move,Static  NaN         406  level2   Park
# 249       Move,Hiding  NaN         387  level1    Kim
# 167            Static  NaN         375  level1    Kim
# 183  Down,Move,Static  NaN         340  level0  First
# 248       Move,Hiding  NaN         336  level1    Kim
# 266       Move,Static  NaN         334  level1   Park
# 186         Down,Move  NaN         333  level0    Kim
# 267       Move,Static  NaN         328  level1   Park

# %%
df_loc_filt_dup['dt_sub'] = df_loc_filt_dup[['Selection starts', 'Selection ends']].apply(tuple, axis=1) #Create a tuple (Date1,Date2)
list_selection = df_loc_filt_dup.groupby(["sublocation"])['dt_sub'].apply(list)  #Create of all intervals grouped.
f_list_selection = list_selection.apply(merge_intervals)   #Use above function to create a grouped list of min,max of each overlaped interval.

time_locat = pd.DataFrame(f_list_selection.apply(lambda x: sum([(y[1]-y[0]).seconds for y in x])))
time_locat.reset_index(inplace=True)

# %%
print(time_locat.dt_sub.sum())
time_locat.sort_values("dt_sub",ascending=False)
# Out:
# 8202
#                sublocation  dt_sub
# 13             living room    1941
# 12                 kitchen    1439
# 1                     cave    1168
# 11                  garden    1025
# 2            da hye's room     858
# 4                 entrance     421
# 0                 basement     337
# 5        entrance-intercom     218
# 8          entrance-street     166
# 6          entrance-stairs     155
# 7   entrance-stairs garage     115
# 15              sauna room      74
# 14    mr. & mrs. park room      70
# 9     first floor-corridor      62
# 3           da song's room      52
# 16        secondary garden      44
# 10                  garage      41
# 17                  toilet      16

# %%
time_subloc=time_locat.groupby("sublocation").agg({"dt_sub":"sum"})
time_subloc["pct_sub"] = time_subloc.apply(lambda x:np.round(100 * x / x.sum(),1))
#time_subloc
time_subloc=time_subloc.reset_index().sort_values("pct_sub",ascending=False)
time_subloc["location"]="Park's House"

# %%
time_subloc
# Out:
#                sublocation  dt_sub  pct_sub      location
# 13             living room    1941     23.7  Park's House
# 12                 kitchen    1439     17.5  Park's House
# 1                     cave    1168     14.2  Park's House
# 11                  garden    1025     12.5  Park's House
# 2            da hye's room     858     10.5  Park's House
# 4                 entrance     421      5.1  Park's House
# 0                 basement     337      4.1  Park's House
# 5        entrance-intercom     218      2.7  Park's House
# 8          entrance-street     166      2.0  Park's House
# 6          entrance-stairs     155      1.9  Park's House
# 7   entrance-stairs garage     115      1.4  Park's House
# 15              sauna room      74      0.9  Park's House
# 14    mr. & mrs. park room      70      0.9  Park's House
# 9     first floor-corridor      62      0.8  Park's House
# 3           da song's room      52      0.6  Park's House
# 10                  garage      41      0.5  Park's House
# 16        secondary garden      44      0.5  Park's House
# 17                  toilet      16      0.2  Park's House

# %% [markdown]
# ## Merge

# %%
time_loc_merg=time_loc.merge(time_subloc,on="location",how="left")
time_loc_merg
# Out:
#                  location   pct             sublocation  dt_sub  pct_sub
# 0             Kim's House  13.9                     NaN     NaN      NaN
# 1           Mr.Park's car   6.0                     NaN     NaN      NaN
# 2   Other Seoul locations  11.5                     NaN     NaN      NaN
# 3            Park's House  65.8             Living room  1941.0     23.7
# 4            Park's House  65.8                 Kitchen  1439.0     17.5
# 5            Park's House  65.8                    Cave  1168.0     14.2
# 6            Park's House  65.8                  Garden  1025.0     12.5
# 7            Park's House  65.8           Da Hye's room   858.0     10.5
# 8            Park's House  65.8                Entrance   421.0      5.1
# 9            Park's House  65.8                Basement   337.0      4.1
# 10           Park's House  65.8       Entrance-intercom   218.0      2.7
# 11           Park's House  65.8         Entrance-street   166.0      2.0
# 12           Park's House  65.8         Entrance-stairs   155.0      1.9
# 13           Park's House  65.8  Entrance-stairs garage   115.0      1.4
# 14           Park's House  65.8              Sauna room    74.0      0.9
# 15           Park's House  65.8    Mr. & Mrs. Park room    70.0      0.9
# 16           Park's House  65.8    First floor-corridor    62.0      0.8
# 17           Park's House  65.8          Da Song's room    52.0      0.6
# 18           Park's House  65.8                  Garage    41.0      0.5
# 19           Park's House  65.8        Secondary Garden    44.0      0.5
# 20           Park's House  65.8                  Toilet    16.0      0.2
# 21                Stadium   3.1                     NaN     NaN      NaN

# %% [markdown]
# ## Heat ocupation floor map Viz

# %% [markdown]
# ### JSON creation

# %%
#df_loc_filt=df[df["location"]=="Park's House"]
df_loc_filt=df_filt.copy()

# %%
print(df_loc_filt["Selection ends"][46])
print((df_loc_filt["Selection ends"].max()-df_loc_filt["Selection starts"].min()))
print((df_loc_filt["Selection ends"].max()-df_loc_filt["Selection starts"].min()).seconds)
# Out:
# 2020-11-16 00:25:18
# 0 days 01:54:06
# 6846

# %%
#Transforming the selection end into seconds
df_loc_filt["end_seconds"]=(df_loc_filt["Selection ends"].dt.hour*3600)+(df_loc_filt["Selection ends"].dt.minute*60)+(df_loc_filt["Selection ends"].dt.second)

# %%
mini=738 #from df_loc_filt["Selection starts"].min()
duration=(df_loc_filt["Selection ends"].max()-df_loc_filt["Selection starts"].min()).seconds
duration
# Out:
# 6846

# %%
#Normalizing the duration in seconds
df_loc_filt["end_seconds_norm"]=np.round(100*((df_loc_filt["end_seconds"]-mini)/(duration)),0)
df_loc_filt
# Out:
#      scene                                description      location  \
# 0      3.0             Ki Woo Arrives at Park's House  Park's House
# 1      3.0             Ki Woo Arrives at Park's House  Park's House
# 2      3.0             Ki Woo Arrives at Park's House  Park's House
# 3      3.0             Ki Woo Arrives at Park's House  Park's House
# 4      3.0  Ki Woo Arrives at Park's House+ Interview  Park's House
# ..     ...                                        ...           ...
# 344   10.0                        Ki Woo becomes rich  Park's House
# 345   10.0                        Ki Woo becomes rich  Park's House
# 346   10.0                        Ki Woo becomes rich  Park's House
# 347   10.0                        Ki Woo becomes rich  Park's House
# 348   10.0                        Ki Woo becomes rich  Park's House
#
#            sublocation   character    Selection starts      Selection ends  \
# 0      entrance-street      Ki Woo 2020-11-16 00:12:18 2020-11-16 00:12:33
# 1    entrance-intercom      Ki Woo 2020-11-16 00:12:33 2020-11-16 00:13:01
# 2             entrance      Ki Woo 2020-11-16 00:13:01 2020-11-16 00:13:52
# 3             entrance  Moon Gwang 2020-11-16 00:13:19 2020-11-16 00:13:52
# 4              kitchen      Ki Woo 2020-11-16 00:13:52 2020-11-16 00:15:35
# ..                 ...         ...                 ...                 ...
# 344           basement     Ki Taek 2020-11-16 02:05:15 2020-11-16 02:05:28
# 345            kitchen     Ki Taek 2020-11-16 02:05:28 2020-11-16 02:05:47
# 346           entrance     Ki Taek 2020-11-16 02:05:47 2020-11-16 02:05:54
# 347        living room     Ki Taek 2020-11-16 02:05:54 2020-11-16 02:06:08
# 348             garden     Ki Taek 2020-11-16 02:06:08 2020-11-16 02:06:24
#
#        Diff. State     Movement Note  difference   level Family  end_seconds  \
# 0    0:00:15   NaN      Move,Up  NaN          15  level0    Kim          753
# 1    0:00:28   NaN           Up  NaN          28  level0    Kim          781
# 2    0:00:51   NaN      Move,Up  NaN          51  level1    Kim          832
# 3    0:00:33   NaN         Move  NaN          33  level1  First          832
# 4    0:01:43   NaN  Move,Static  NaN         103  level1    Kim          935
# ..       ...   ...          ...  ...         ...     ...    ...          ...
# 344  0:00:13   NaN           Up  NaN          13  level0    Kim         7528
# 345  0:00:19   NaN         Move  NaN          19  level1    Kim         7547
# 346  0:00:07   NaN         Move  NaN           7  level1    Kim         7554
# 347  0:00:14   NaN         Move  NaN          14  level1    Kim         7568
# 348  0:00:16   NaN         Move  NaN          16  level1    Kim         7584
#
#      end_seconds_norm
# 0                 0.0
# 1                 1.0
# 2                 1.0
# 3                 1.0
# 4                 3.0
# ..                ...
# 344              99.0
# 345              99.0
# 346             100.0
# 347             100.0
# 348             100.0
#
# [349 rows x 16 columns]

# %%
df_loc_filt['dt_sub_sl'] = df_loc_filt[['Selection starts', 'Selection ends']].apply(tuple, axis=1) #Create a tuple (Date1,Date2)
#by room
list_slider= df_loc_filt.groupby(["end_seconds_norm","sublocation"])['dt_sub_sl'].apply(list)  #Create of all intervals grouped.
#by floor
#list_slider= df_loc_filt.groupby(["end_seconds_norm","level"])['dt_sub_sl'].apply(list)  #Create of all intervals grouped.

f_list_slider = list_slider.apply(merge_intervals)   #Use above function to create a grouped list of min,max of each overlaped interval.
time_slider = pd.DataFrame(f_list_slider.apply(lambda x: sum([(y[1]-y[0]).seconds for y in x])))
time_slider.reset_index(inplace=True)

# %%
time_slider_gr=time_slider.groupby(["end_seconds_norm","sublocation"]).agg({"dt_sub_sl":"sum"})#.unstack(fill_value=0).stack()
#time_slider_gr=time_slider.groupby(["end_seconds_norm","level"]).agg({"dt_sub_sl":"sum"})#.unstack(fill_value=0).stack()

#Not needed a pctg column
#time_slider_gr["pct_slider"] = time_slider_gr.groupby(level=0).apply(lambda x:np.round(100 * (x / x.sum()),1))
time_slider_gr.reset_index(inplace=True)

# %%
time_slider_gr["sublocation"]=time_slider_gr["sublocation"].str.lower()
#replace some characters to match the name of the center elements in the svg
time_slider_gr["sublocation"].replace(" ",'_',regex=True,inplace=True)
time_slider_gr["sublocation"].replace('&','',regex=True,inplace=True)
time_slider_gr["sublocation"].replace('\\._','_',regex=True,inplace=True)
time_slider_gr["sublocation"].replace("'",'_',regex=True,inplace=True)

# %%
time_slider_gr=time_slider_gr[~time_slider_gr["sublocation"].isin(["toilet","sauna_room"])]#,"entrance-intercom"
time_slider_gr.sublocation.value_counts()
# Out:
# kitchen                   29
# living_room               22
# entrance                  19
# entrance-stairs           15
# garden                    14
# basement                  13
# entrance-street            9
# cave                       9
# da_hye_s_room              8
# entrance-stairs_garage     8
# first_floor-corridor       6
# entrance-intercom          6
# garage                     4
# da_song_s_room             3
# secondary_garden           2
# mr__mrs_park_room          2
# Name: sublocation, dtype: int64

# %%
#pd.set_option('display.max_rows', 10)
time_slider_gr.to_json("data_out/house-ocupation.json",orient='records');

# %% [markdown]
# ### Check: comparing with D3 calculation

# %%
total=time_slider_gr.dt_sub_sl.sum()
print(total)
#check=time_slider_gr.groupby(["level"]).agg({"dt_sub_sl":"sum"})
check=time_slider_gr.groupby(["sublocation"]).agg({"dt_sub_sl":"sum"})
check["pct"]=np.round(100*(check["dt_sub_sl"] / total),1)
check.sort_values("pct",ascending=False)

#Why there is a mismatch between this and the sublocation analysis of 4.1? Because
#we are grouping by ["end_seconds_norm","sublocation"] rather than by ["sublocation"]
#of the first case. Solution: compute the duration code in D3.js . Not feasible.
# Out:
# 10521
#                         dt_sub_sl   pct
# sublocation
# living_room                  3037  28.9
# kitchen                      1622  15.4
# garden                       1529  14.5
# cave                         1281  12.2
# da_hye_s_room                1264  12.0
# basement                      444   4.2
# entrance                      421   4.0
# entrance-intercom             218   2.1
# entrance-street               166   1.6
# entrance-stairs               155   1.5
# entrance-stairs_garage        115   1.1
# mr__mrs_park_room              70   0.7
# first_floor-corridor           62   0.6
# da_song_s_room                 52   0.5
# garage                         41   0.4
# secondary_garden               44   0.4

# %% [markdown]
# ### Analysis over time

# %%
time_slider_gr['end_range'] = pd.cut(time_slider_gr.end_seconds_norm, [0,20,40,60,80,100], include_lowest=True)
time_slider_gr
# Out:
#      end_seconds_norm        sublocation  dt_sub_sl       end_range
# 0                 0.0    entrance-street         15  (-0.001, 20.0]
# 1                 1.0           entrance         51  (-0.001, 20.0]
# 2                 1.0  entrance-intercom         28  (-0.001, 20.0]
# 3                 2.0            kitchen         15  (-0.001, 20.0]
# 4                 2.0   secondary_garden         23  (-0.001, 20.0]
# ..                ...                ...        ...             ...
# 167              99.0    entrance-street          7   (80.0, 100.0]
# 168              99.0            kitchen         19   (80.0, 100.0]
# 169             100.0           entrance          7   (80.0, 100.0]
# 170             100.0             garden         79   (80.0, 100.0]
# 171             100.0        living_room         14   (80.0, 100.0]
#
# [169 rows x 4 columns]

# %%
check=time_slider_gr.groupby(["end_range","sublocation"]).agg({"dt_sub_sl":"sum"})
#check=time_slider_gr.groupby(["end_range","level"]).agg({"dt_sub_sl":"sum"})

check["pct"] = check.groupby(level=0).apply(lambda x:100 * x / x.sum())
check.sort_values(["end_range","pct"],ascending=[True,False],inplace=True)
check.reset_index(inplace=True)

# %%
check.head(50)
# Out:
#          end_range             sublocation  dt_sub_sl        pct
# 0   (-0.001, 25.0]                 kitchen      615.0  36.261792
# 1   (-0.001, 25.0]           da_hye_s_room      316.0  18.632075
# 2   (-0.001, 25.0]                entrance      191.0  11.261792
# 3   (-0.001, 25.0]             living_room      127.0   7.488208
# 4   (-0.001, 25.0]         entrance-street      103.0   6.073113
# 5   (-0.001, 25.0]       entrance-intercom      101.0   5.955189
# 6   (-0.001, 25.0]         entrance-stairs       93.0   5.483491
# 7   (-0.001, 25.0]                  garden       34.0   2.004717
# 8   (-0.001, 25.0]                basement       28.0   1.650943
# 9   (-0.001, 25.0]    first_floor-corridor       25.0   1.474057
# 10  (-0.001, 25.0]        secondary_garden       23.0   1.356132
# 11  (-0.001, 25.0]          da_song_s_room       20.0   1.179245
# 12  (-0.001, 25.0]  entrance-stairs_garage       11.0   0.648585
# 13  (-0.001, 25.0]       mr__mrs_park_room        9.0   0.530660
# 14  (-0.001, 25.0]                    cave        NaN        NaN
# 15  (-0.001, 25.0]                  garage        NaN        NaN
# 16    (25.0, 50.0]             living_room      960.0  51.919957
# 17    (25.0, 50.0]                 kitchen      242.0  13.088156
# 18    (25.0, 50.0]                entrance      159.0   8.599243
# 19    (25.0, 50.0]                basement      134.0   7.247161
# 20    (25.0, 50.0]       entrance-intercom       96.0   5.191996
# 21    (25.0, 50.0]                  garden       87.0   4.705246
# 22    (25.0, 50.0]          da_song_s_room       32.0   1.730665
# 23    (25.0, 50.0]                  garage       24.0   1.297999
# 24    (25.0, 50.0]         entrance-stairs       22.0   1.189832
# 25    (25.0, 50.0]  entrance-stairs_garage       22.0   1.189832
# 26    (25.0, 50.0]        secondary_garden       21.0   1.135749
# 27    (25.0, 50.0]           da_hye_s_room       19.0   1.027582
# 28    (25.0, 50.0]         entrance-street       18.0   0.973499
# 29    (25.0, 50.0]    first_floor-corridor       13.0   0.703083
# 30    (25.0, 50.0]                    cave        NaN        NaN
# 31    (25.0, 50.0]       mr__mrs_park_room        NaN        NaN
# 32    (50.0, 75.0]             living_room     1875.0  38.884280
# 33    (50.0, 75.0]                    cave     1033.0  21.422646
# 34    (50.0, 75.0]           da_hye_s_room      828.0  17.171298
# 35    (50.0, 75.0]                 kitchen      644.0  13.355454
# 36    (50.0, 75.0]                  garden      131.0   2.716715
# 37    (50.0, 75.0]                basement       96.0   1.990875
# 38    (50.0, 75.0]  entrance-stairs_garage       72.0   1.493156
# 39    (50.0, 75.0]                entrance       59.0   1.223559
# 40    (50.0, 75.0]         entrance-stairs       27.0   0.559934
# 41    (50.0, 75.0]    first_floor-corridor       24.0   0.497719
# 42    (50.0, 75.0]         entrance-street       18.0   0.373289
# 43    (50.0, 75.0]                  garage       15.0   0.311074
# 44    (50.0, 75.0]          da_song_s_room        NaN        NaN
# 45    (50.0, 75.0]       entrance-intercom        NaN        NaN
# 46    (50.0, 75.0]       mr__mrs_park_room        NaN        NaN
# 47    (50.0, 75.0]        secondary_garden        NaN        NaN
# 48   (75.0, 100.0]                  garden     1277.0  59.285051
# 49   (75.0, 100.0]                    cave      248.0  11.513463

# %%
def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x'] +.02, point['y'], str(point['val']))

# %%
fig, ax = plt.subplots(1,1)
fig.set_size_inches(10, 11)
label_point(check.end_range.cat.codes, check.pct, check.sublocation, ax)  

fig=sns.catplot(x="end_range", y="pct", hue="sublocation", kind="swarm",data=check,ax=ax,legend=False,legend_out=True);
plt.close(2);
#fig=sns.catplot(x="end_range", y="pct", hue="level", kind="swarm",data=check,ax=ax,legend=False);
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
#I am not able to save it
#fig.get_figure()
#fig.savefig('C:/Users/Javier San Miguel/Desktop/Data/Data visualization/Parasite/doc/img/roomocupation.jpg',dpi=200)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-830-ad5c255d22db> in <module>
# ----> 1 fig.get_figure()
#       2 fig.savefig('C:/Users/Javier San Miguel/Desktop/Data/Data visualization/Parasite/doc/img/roomocupation.jpg',dpi=200)
#
# AttributeError: 'FacetGrid' object has no attribute 'get_figure'

# %% [markdown]
# # Characters Dataset

# %%
#ch.rename({"Link Image":"urlImage"},axis=1,inplace=True)
ch.dtypes
ch["id"]=ch["Character"].replace(" ",'_',regex=True)
ch.dropna(axis=0,subset=['urlImage'],inplace=True)

# %%
ch
# Out:
#     Character Family             Actor                         Role  \
# 0      Ki Woo    Kim      Woo-sik Choi              English Teacher
# 1     Ki Jung    Kim       So-dam Park                  Art Teacher
# 2     Ki Taek    Kim      Kang-ho Song                    Chauffeur
# 3  Chung Sook    Kim      Hye-jin Jang                  Housekeeper
# 4    Yeon Kyo   Park      Yeo-jeong Jo                       Mother
# 5    Mr. Park   Park      Sun-kyun Lee                       Father
# 6      Da Hye   Park        Ji-so Jung                     Daughter
# 7     Da Song   Park     Hyun-jun Jung                          Son
# 8  Moon Gwang    NaN     Jeong-eun Lee            First Housekeeper
# 9     Geun Se    NaN  Myeong-hoon Park  First Housekeeper's husband
#
#                                             urlImage          id
# 0  https://github.com/javiersgdtu/javiersgvisual/...      Ki_Woo
# 1  https://github.com/javiersgdtu/javiersgvisual/...     Ki_Jung
# 2  https://github.com/javiersgdtu/javiersgvisual/...     Ki_Taek
# 3  https://raw.githubusercontent.com/javiersgdtu/...  Chung_Sook
# 4  https://github.com/javiersgdtu/javiersgvisual/...    Yeon_Kyo
# 5  https://github.com/javiersgdtu/javiersgvisual/...    Mr._Park
# 6  https://github.com/javiersgdtu/javiersgvisual/...      Da_Hye
# 7  https://github.com/javiersgdtu/javiersgvisual/...     Da_Song
# 8  https://github.com/javiersgdtu/javiersgvisual/...  Moon_Gwang
# 9  https://github.com/javiersgdtu/javiersgvisual/...     Geun_Se

# %%
ch.to_json("data_out/characters.json",orient='records');

# %% [markdown]
# # Deleted code

# %%
#In 4. First method using the dissapeared locationid attribute =IF(E4=E3;D3;D3+1)
df_loc_gr=df_loc.groupby(["locationid","location"],as_index=False).agg({"Selection starts":"first","Selection ends":"last"})
df_loc_gr['difference_loc']=df_loc_gr['Selection ends']-df_loc_gr['Selection starts']
#df['difference_loc']=df['difference_loc'].dt.seconds
pd.set_option('display.max_rows', 73)
#df_loc_gr.difference_loc.sum() #To check whether the duration is similar to the film one.
df_loc_gr.head()

# %%
df_loc_sum=df_loc_gr.groupby(["location"]).agg({"difference_loc":"sum"})
df_loc_sum["pct"] = df_loc_sum.apply(lambda x:100 * x / x.sum())

df_loc_sum.sort_values("difference_loc",ascending=False)

# %%
#-------In the sublocation fields
#print(df_loc_filt.shape)
#Actually not really needed with the function used above.
#df_loc_filt_dup=df_loc_filt.drop_duplicates(subset=['locationid', 'sublocation','Selection starts','Selection ends'], keep='last')
#print(df_loc_filt_dup.shape)

# %%
#First approach discarded: Create intervals
#df_loc_filt_dup["interval"]=[pd.Interval(j["Selection starts"],j["Selection ends"],closed='both') for i,j in df_loc_filt_dup.iterrows()]
#df_loc_filt_dup["interval"][46].overlaps(df_loc_filt_dup["interval"][47])
#df_loc_filt_dup.head(20)
